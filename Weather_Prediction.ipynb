# %%
# Weather Prediction (Sunny/Rainy) using Decision Tree

import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# Step 1: Create dataset
data = {
    "Temperature": [30,25,27,18,20,22,35,28,15,10],
    "Humidity": [85,80,75,96,90,88,70,65,95,98],
    "Weather": ["Rainy","Rainy","Sunny","Rainy","Rainy","Rainy","Sunny","Sunny","Rainy","Rainy"]
}
df = pd.DataFrame(data)

# Step 2: Prepare data
X = df[["Temperature", "Humidity"]]
y = df["Weather"]

# Step 3: Split & train
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
model = DecisionTreeClassifier()
model.fit(X_train, y_train)

# Step 4: Predict
y_pred = model.predict(X_test)

# Step 5: Accuracy
print("Accuracy:", accuracy_score(y_test, y_pred))

# Step 6: Custom prediction
new_data = pd.DataFrame({"Temperature": [26], "Humidity": [82]})
print("Predicted Weather:", model.predict(new_data)[0])
# Out:
# Accuracy: 0.6666666666666666
# Predicted Weather: Rainy
